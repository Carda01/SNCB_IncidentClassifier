# %%
path = "/content/drive/MyDrive/Graduate/Semester 1 (Fall 2024)/INFO-H423 Data Mining/Project/SNCB_IncidentClassifier/models/anomaly_detection/classification"

# %%
# %cd $path
# %ls
# Out:
# /content/drive/MyDrive/Graduate/Semester 1 (Fall 2024)/INFO-H423 Data Mining/Project/SNCB_IncidentClassifier/models/anomaly_detection/classification
# '1201 - LSTM eval.ipynb'   data_norm/           main.py        results/
#  data_all/                 lstm_classifier.py   __pycache__/

# %%
import lstm_classifier as lc

# %%
normal_only = False
perc = 10

# %%
LC = lc.LSTMClassifier(normal_only, perc)
# Out:
# [__init__] start
# [__init__] end

# %%
LC.load_data()
LC.encode_seqs()
LC.prepare_train_data()
LC.create_model()
LC.train_model()
LC.evaluate()
LC.save_results()
# Out:
# [load_data] start
# [load_data] end
# [encode_seqs] start
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# 4295 150
# [encode_seqs] end
# [prepare_train_data] start
# [prepare_train_data] end
# [create_model] start
# [create_model] end
# [train_model] start
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/base_optimizer.py:33: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# Epoch 1/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 13s 156ms/step - accuracy: 0.2840 - loss: 2.2420 - val_accuracy: 0.4468 - val_loss: 1.6527
# Epoch 2/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 19s 139ms/step - accuracy: 0.5129 - loss: 1.5362 - val_accuracy: 0.4900 - val_loss: 1.4290
# Epoch 3/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.5766 - loss: 1.3622 - val_accuracy: 0.5797 - val_loss: 1.4319
# Epoch 4/100
# ...

# %%
normal_only = True
perc = 10
LC = lc.LSTMClassifier(normal_only, perc)
LC.load_data()
LC.encode_seqs()
LC.prepare_train_data()
LC.create_model()
LC.train_model()
LC.evaluate()
LC.save_results()
# Out:
# [__init__] start
# [__init__] end
# [load_data] start
# [load_data] end
# [encode_seqs] start
# 3002 150
# [encode_seqs] end
# [prepare_train_data] start
# [prepare_train_data] end
# [create_model] start
# [create_model] end
# [train_model] start
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/base_optimizer.py:33: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 9s 122ms/step - accuracy: 0.2330 - loss: 2.3406 - val_accuracy: 0.3420 - val_loss: 1.8328
# Epoch 2/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 0.3504 - loss: 1.8520 - val_accuracy: 0.3872 - val_loss: 1.7790
# Epoch 3/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 10s 106ms/step - accuracy: 0.4023 - loss: 1.7200 - val_accuracy: 0.3658 - val_loss: 1.7580
# Epoch 4/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 131ms/step - accuracy: 0.4256 - loss: 1.6381 - val_accuracy: 0.4014 - val_loss: 1.7189
# Epoch 5/100
# ...

# %%
normal_only = False
perc = 15
LC = lc.LSTMClassifier(normal_only, perc)
LC.load_data()
LC.encode_seqs()
LC.prepare_train_data()
LC.create_model()
LC.train_model()
LC.evaluate()
LC.save_results()
# Out:
# [__init__] start
# [__init__] end
# [load_data] start
# [load_data] end
# [encode_seqs] start
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# 6408 150
# [encode_seqs] end
# [prepare_train_data] start
# [prepare_train_data] end
# [create_model] start
# [create_model] end
# [train_model] start
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/base_optimizer.py:33: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# Epoch 1/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 15s 131ms/step - accuracy: 0.3079 - loss: 2.1632 - val_accuracy: 0.5162 - val_loss: 1.5345
# Epoch 2/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 20s 128ms/step - accuracy: 0.4885 - loss: 1.6306 - val_accuracy: 0.4236 - val_loss: 1.6559
# Epoch 3/100
# ...

# %%
normal_only = True
perc = 15
LC = lc.LSTMClassifier(normal_only, perc)
LC.load_data()
LC.encode_seqs()
LC.prepare_train_data()
LC.create_model()
LC.train_model()
LC.evaluate()
LC.save_results()
# Out:
# [__init__] start
# [__init__] end
# [load_data] start
# [load_data] end
# [encode_seqs] start
# 4461 150
# [encode_seqs] end
# [prepare_train_data] start
# [prepare_train_data] end
# [create_model] start
# [create_model] end
# [train_model] start
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/base_optimizer.py:33: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# Epoch 1/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 11s 114ms/step - accuracy: 0.2663 - loss: 2.2074 - val_accuracy: 0.3728 - val_loss: 1.7515
# Epoch 2/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - accuracy: 0.3526 - loss: 1.7979 - val_accuracy: 0.4064 - val_loss: 1.6794
# Epoch 3/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 7s 107ms/step - accuracy: 0.3938 - loss: 1.7221 - val_accuracy: 0.4112 - val_loss: 1.6475
# Epoch 4/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 11s 117ms/step - accuracy: 0.4094 - loss: 1.6754 - val_accuracy: 0.4160 - val_loss: 1.6374
# Epoch 5/100
# ...

# %%
normal_only = False
perc = 20
LC = lc.LSTMClassifier(normal_only, perc)
LC.load_data()
LC.encode_seqs()
LC.prepare_train_data()
LC.create_model()
LC.train_model()
LC.evaluate()
LC.save_results()
# Out:
# [__init__] start
# [__init__] end
# [load_data] start
# [load_data] end
# [encode_seqs] start
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# 8537 150
# [encode_seqs] end
# [prepare_train_data] start
# [prepare_train_data] end
# [create_model] start
# [create_model] end
# [train_model] start
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/base_optimizer.py:33: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# Epoch 1/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.3463 - loss: 2.0220 - val_accuracy: 0.5079 - val_loss: 1.5809
# Epoch 2/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 21s 132ms/step - accuracy: 0.5057 - loss: 1.5455 - val_accuracy: 0.5782 - val_loss: 1.4434
# Epoch 3/100
# ...

# %%
normal_only = True
perc = 20
LC = lc.LSTMClassifier(normal_only, perc)
LC.load_data()
LC.encode_seqs()
LC.prepare_train_data()
LC.create_model()
LC.train_model()
LC.evaluate()
LC.save_results()
# Out:
# [__init__] start
# [__init__] end
# [load_data] start
# [load_data] end
# [encode_seqs] start
# 5920 150
# [encode_seqs] end
# [prepare_train_data] start
# [prepare_train_data] end
# [create_model] start
# [create_model] end
# [train_model] start
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/base_optimizer.py:33: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - accuracy: 0.2485 - loss: 2.1841 - val_accuracy: 0.3571 - val_loss: 1.7977
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 11s 120ms/step - accuracy: 0.3518 - loss: 1.8089 - val_accuracy: 0.3595 - val_loss: 1.7339
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 21s 122ms/step - accuracy: 0.3572 - loss: 1.7596 - val_accuracy: 0.3800 - val_loss: 1.7158
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 21s 127ms/step - accuracy: 0.3895 - loss: 1.7141 - val_accuracy: 0.3993 - val_loss: 1.7356
# Epoch 5/100
# ...

# %%
normal_only = False
perc = 30
LC = lc.LSTMClassifier(normal_only, perc)
LC.load_data()
LC.encode_seqs()
LC.prepare_train_data()
LC.create_model()
LC.train_model()
LC.evaluate()
LC.save_results()
# Out:
# [__init__] start
# [__init__] end
# [load_data] start
# [load_data] end
# [encode_seqs] start
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# 12777 150
# [encode_seqs] end
# [prepare_train_data] start
# [prepare_train_data] end
# [create_model] start
# [create_model] end
# [train_model] start
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/base_optimizer.py:33: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# Epoch 1/100
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 26s 117ms/step - accuracy: 0.3387 - loss: 1.9887 - val_accuracy: 0.5344 - val_loss: 1.4627
# Epoch 2/100
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 40s 114ms/step - accuracy: 0.4951 - loss: 1.5386 - val_accuracy: 0.5372 - val_loss: 1.5231
# Epoch 3/100
# ...

# %%
normal_only = True
perc = 30
LC = lc.LSTMClassifier(normal_only, perc)
LC.load_data()
LC.encode_seqs()
LC.prepare_train_data()
LC.create_model()
LC.train_model()
LC.evaluate()
LC.save_results()
# Out:
# [__init__] start
# [__init__] end
# [load_data] start
# [load_data] end
# [encode_seqs] start
# 8879 150
# [encode_seqs] end
# [prepare_train_data] start
# [prepare_train_data] end
# [create_model] start
# [create_model] end
# [train_model] start
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/base_optimizer.py:33: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# Epoch 1/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 19s 121ms/step - accuracy: 0.2793 - loss: 2.1329 - val_accuracy: 0.3467 - val_loss: 1.8363
# Epoch 2/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 21s 121ms/step - accuracy: 0.3462 - loss: 1.8062 - val_accuracy: 0.3685 - val_loss: 1.7709
# Epoch 3/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 20s 119ms/step - accuracy: 0.3717 - loss: 1.7696 - val_accuracy: 0.3725 - val_loss: 1.7761
# Epoch 4/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 21s 121ms/step - accuracy: 0.3899 - loss: 1.7306 - val_accuracy: 0.3870 - val_loss: 1.7578
# Epoch 5/100
# ...

# %%
normal_only = False
perc = 50
LC = lc.LSTMClassifier(normal_only, perc)
LC.load_data()
LC.encode_seqs()
LC.prepare_train_data()
LC.create_model()
LC.train_model()
LC.evaluate()
LC.save_results()
# Out:
# [__init__] start
# [__init__] end
# [load_data] start
# [load_data] end
# [encode_seqs] start
# Unknown: 1040
# Unknown: 1040
# Unknown: 1040
# Unknown: 1040
# Unknown: 1040
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# Unknown: 1038
# 21291 150
# [encode_seqs] end
# [prepare_train_data] start
# [prepare_train_data] end
# [create_model] start
# [create_model] end
# [train_model] start
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/base_optimizer.py:33: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# Epoch 1/100
# 332/332 ━━━━━━━━━━━━━━━━━━━━ 46s 133ms/step - accuracy: 0.3369 - loss: 1.9404 - val_accuracy: 0.4871 - val_loss: 1.5389
# Epoch 2/100
# ...

# %%
normal_only = True
perc = 50
LC = lc.LSTMClassifier(normal_only, perc)
LC.load_data()
LC.encode_seqs()
LC.prepare_train_data()
LC.create_model()
LC.train_model()
LC.evaluate()
LC.save_results()
# Out:
# [__init__] start
# [__init__] end
# [load_data] start
# [load_data] end
# [encode_seqs] start
# 14767 150
# [encode_seqs] end
# [prepare_train_data] start
# [prepare_train_data] end
# [create_model] start
# [create_model] end
# [train_model] start
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/base_optimizer.py:33: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# Epoch 1/100
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 30s 121ms/step - accuracy: 0.2781 - loss: 2.0449 - val_accuracy: 0.3395 - val_loss: 1.8128
# Epoch 2/100
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 29s 125ms/step - accuracy: 0.3533 - loss: 1.7805 - val_accuracy: 0.3656 - val_loss: 1.7805
# Epoch 3/100
